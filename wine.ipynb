# %%
# for numerical computing
import numpy as np
# for dataframes
import pandas as pd
# for easier visualization
import seaborn as sns
# for visualization and to display plots
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#reading the csv file and printing the data
data1=pd.read_csv('C:/Users/Dell PC/Desktop/ProjectSummer/winequality_winequality-red.csv',sep=';')
data2=pd.read_csv('C:/Users/Dell PC/Desktop/ProjectSummer/winequality_winequality-white.csv',sep=';')
data1['color']='red'
data2['color']='white'
data=data1.append(data2)
print("Size of data is:",data.shape)
data.columns
# Out:
# Size of data is: (6497, 13)
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 10              6.7             0.580         0.08            1.80      0.097
# ...

# %%
data.columns=['fa','va','ca','rs','cl','fsd','tsd','den','ph','so','al','quality','color']

# %%
data.head()
# Out:
#      fa    va    ca   rs     cl   fsd   tsd     den    ph    so   al  quality  \
# 0   7.4  0.70  0.00  1.9  0.076  11.0  34.0  0.9978  3.51  0.56  9.4        5
# 1   7.8  0.88  0.00  2.6  0.098  25.0  67.0  0.9968  3.20  0.68  9.8        5
# 2   7.8  0.76  0.04  2.3  0.092  15.0  54.0  0.9970  3.26  0.65  9.8        5
# 3  11.2  0.28  0.56  1.9  0.075  17.0  60.0  0.9980  3.16  0.58  9.8        6
# 4   7.4  0.70  0.00  1.9  0.076  11.0  34.0  0.9978  3.51  0.56  9.4        5
#
#   color
# 0   red
# 1   red
# 2   red
# 3   red
# 4   red

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.dtypes
# Out:
# fa         float64
# va         float64
# ca         float64
# rs         float64
# cl         float64
# fsd        float64
# tsd        float64
# den        float64
# ph         float64
# so         float64
# al         float64
# quality      int64
# color       object
# dtype: object

# %%
#Examining the null values using heatmap
#here the yellow represents 1 i.e,null values present in the data
sns.heatmap(data.isnull(),cmap='viridis')
plt.title("Heat map of null values in columns of numerical data:")
# Out:
# Text(0.5,1,'Heat map of null values in columns of numerical data:')

# %%
#finding the null values column by column using isnull().sum()
data.isnull().sum()
# Out:
# fa         0
# va         0
# ca         0
# rs         0
# cl         0
# fsd        0
# tsd        0
# den        0
# ph         0
# so         0
# al         0
# quality    0
# color      0
# dtype: int64

# %%
#number of white and red wines
sns.countplot(data=data, x="color")

# %%
data['color'].value_counts()
# Out:
# white    4898
# red      1599
# Name: color, dtype: int64

# %% [markdown]
# # Encoding the categorical data values

# %%
enc= { 
          "color":{"white": 1, "red": 0},
     }
data.replace(enc, inplace=True)

# %% [markdown]
# # Plottings for understanding and visualising the data

# %%
sns.countplot(data=data, x="quality")

# %%
correlation=data.corr()
plt.figure(figsize=(12, 5))
sns.heatmap(data.corr(), annot=True, linewidths=0)

# %%
correlation['quality'].sort_values(ascending=False)
# Out:
# quality    1.000000
# al         0.444319
# color      0.119323
# ca         0.085532
# fsd        0.055463
# so         0.038485
# ph         0.019506
# rs        -0.036980
# tsd       -0.041385
# fa        -0.076743
# cl        -0.200666
# va        -0.265699
# den       -0.305858
# Name: quality, dtype: float64

# %%
#Composition of chloride also go down as we go higher in the quality of the wine
sns.barplot(x = 'quality', y = 'al', data = data)
plt.title("graph between quality and al")
# Out:
# Text(0.5,1,'graph between quality and al')

# %%
sns.barplot(x = 'quality', y = 'cl', data = data)
plt.title("graph between quality and cl")
# Out:
# Text(0.5,1,'graph between quality and cl')

# %%
sns.barplot(x = 'quality', y = 'ca', data = data)
plt.title("graph between quality and ca")
# Out:
# Text(0.5,1,'graph between quality and ca')

# %%
sns.barplot(x = 'quality', y = 'va', data = data)
plt.title("Graph between quality and va")
# Out:
# Text(0.5,1,'Graph between quality and va')

# %%
for x in data['quality']:
    if x<=4:
        y=0
    elif x>=5 and x<=7:
        y=1
    elif x>=8 and x<=10:
        y=2
    data['quality']=data['quality'].replace(x,y)

# %%
sns.countplot(data=data, x="quality")

# %%
data['quality'].value_counts()
# Out:
# 1    6053
# 0     246
# 2     198
# Name: quality, dtype: int64

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# Data Preparation

# %%
ar=data.values
# Create separate object for input features
x=data.loc[:, ['fa','va','ca','rs','cl','fsd','tsd','den','ph','so','al','color']]
x=x.values
# Create separate object for target variable
y=data.loc[:,['quality']]
y=y.values

# %% [markdown]
# Resampling: to split train and test set of x

# %%
from sklearn import model_selection
X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,test_size = 0.22, random_state=42)

# %% [markdown]
# Preprocessing the data-StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# Models:

# %%
from sklearn.svm import SVC
svc2 = SVC(C=1.2,gamma = 0.9,kernel= 'rbf')
svc2.fit(X_train, Y_train)
pred_svc2 = svc2.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(pred_svc2,Y_test)*100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 93.91608391608392

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(pred,Y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9349650349650349

# %%
from sklearn.tree import DecisionTreeClassifier
modell = DecisionTreeClassifier()
modell.fit(X_train, Y_train)
pred = modell.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(pred,Y_test)
# Out:
# 0.9062937062937063

# %%
from sklearn.neighbors import KNeighborsClassifier
modelk = KNeighborsClassifier()
modelk.fit(X_train, Y_train)
pred = modelk.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(pred,Y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.9321678321678322

# %%
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_train, Y_train) 
NY_predict=gnb.predict(X_test)
print(accuracy_score(Y_test,NY_predict)*100)
# Out:
# 80.48951048951048
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(X_train,Y_train)
from sklearn.metrics import accuracy_score
Y_prediction = rfc.predict(X_test)

print(accuracy_score(Y_test,Y_prediction)*100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 93.4965034965035
